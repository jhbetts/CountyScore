# %% [markdown]
# # Explore temps .csv and tranform data.

# %%
import pandas as pd
import us
with open("/workspaces/greener/static/greener/dec_feb_temps.csv") as f:
    temps = pd.read_csv(f,comment='#')
temps.head()
# Out:
#        ID            Name    State  Value   Rank  \
# 0  AL-001  Autauga County  Alabama   59.4  123.0
# 1  AL-003  Baldwin County  Alabama   63.8  126.0
# 2  AL-005  Barbour County  Alabama   60.3  123.0
# 3  AL-007     Bibb County  Alabama   58.2  127.0
# 4  AL-009   Blount County  Alabama   56.3  125.0
#
#    Anomaly (1901-2000 base period)  1901-2000 Mean
# 0                              4.0            55.4
# 1                              4.3            59.5
# 2                              3.5            56.8
# 3                              4.2            54.0
# 4                              4.5            51.8

# %%
# get shape of df
temps.shape
# Out:
# (3107, 7)

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "Virgin Islands, U.S.": "VI",
}
temps['State'] = temps['State'].replace(us_state_to_abbrev)

# %%
# select only the county name and value
from numpy import true_divide


temps = temps[['Name', 'Value', 'State']]
temps.rename(columns={"Value":"WinterAvg"}, inplace=True)
temps.head()
# Out:
#              Name  WinterAvg State
# 0  Autauga County       59.4    AL
# 1  Baldwin County       63.8    AL
# 2  Barbour County       60.3    AL
# 3     Bibb County       58.2    AL
# 4   Blount County       56.3    AL

# %%
# Load housing data to join
housing = pd.read_csv("/workspaces/greener/static/greener/home_values_county.csv")
housing.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     county        CA    CA
# 1       139         1         Cook County     county        IL    IL
# 2      1090         2       Harris County     county        TX    TX
# 3      2402         3     Maricopa County     county        AZ    AZ
# 4      2841         4    San Diego County     county        CA    CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#       2000-01-31  ...     2024-08-31     2024-09-30     2024-10-31  \
# ...

# %%
joined = pd.merge(housing, temps, right_on=["Name", 'State'], left_on=['RegionName', 'State'], how='left')
joined.drop(columns=["Name", "State"], inplace=True)
joined.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName  \
# 0      3101         0  Los Angeles County     county        CA
# 1       139         1         Cook County     county        IL
# 2      1090         2       Harris County     county        TX
# 3      2402         3     Maricopa County     county        AZ
# 4      2841         4    San Diego County     county        CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#       2000-01-31     2000-02-29  ...     2024-09-30     2024-10-31  \
# 0  215914.255946  216158.404402  ...  907499.233829  912834.444785
# ...

# %%
joined.shape
# Out:
# (3107, 316)
